# %% [markdown]
# ## 1.3

# %% [markdown]
# Pythonバージョンチェック

# %%
import sys
sys.version
# Out:
# '3.5.2 |Anaconda 4.2.0 (64-bit)| (default, Jul  2 2016, 17:53:06) \n[GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]'

# %% [markdown]
# ### 1.3.1
# 除算チェック（Python3だと小数に）

# %%
7/5
# Out:
# 1.4

# %% [markdown]
# ## 1.5 Numpy

# %%
import numpy as np

# %% [markdown]
# ### 1.5.2  配列

# %%
x = np.array([1.0,2.0,3.0])
print(x)
# Out:
# [ 1.  2.  3.]

# %% [markdown]
# ### 1.5.3 算術演算

# %%
x = np.array([1.0,2.0,3.0])
y = np.array([2.0,4.0,6.0])
print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x / 3)
# Out:
# [ 3.  6.  9.]
# [-1. -2. -3.]
# [  2.   8.  18.]
# [ 0.5  0.5  0.5]
# [ 0.33333333  0.66666667  1.        ]

# %% [markdown]
# ### 1.5.4 N次元配列

# %%
A = np.array([[1,2],[3,4]])
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A.shape
# Out:
# (2, 2)

# %%
A.dtype # 要素のデータ型
# Out:
# dtype('int64')

# %%
B = np.array([[3,0],[0,6]])
A + B
# Out:
# array([[ 4,  2],
#        [ 3, 10]])

# %%
A - B
# Out:
# array([[-2,  2],
#        [ 3, -2]])

# %%
A * B # 要素ごとに計算、内積ではない点に注意
# Out:
# array([[ 3,  0],
#        [ 0, 24]])

# %%
A / B # divide by zero
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   if __name__ == '__main__':
# array([[ 0.33333333,         inf],
#        [        inf,  0.66666667]])

# %% [markdown]
# ### 1.5.5 ブロードキャスト

# %%
A = np.array([[1,2],[3,4]])
B = np.array([10,20])
A * B # Bが自動で[[10,20],[10,20]]へと拡張される
# Out:
# array([[10, 40],
#        [30, 80]])

# %%
A + B
# Out:
# array([[11, 22],
#        [13, 24]])

# %% [markdown]
# ### 1.5.6 要素へのアクセス

# %%
X = np.array([[51,55],[14,19],[0,4]])
print(X)
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]

# %%
X[0] # 行ごと
# Out:
# array([51, 55])

# %%
X[:,0] # 列ごと
# Out:
# array([51, 14,  0])

# %%
X > 15
# Out:
# array([[ True,  True],
#        [False,  True],
#        [False, False]], dtype=bool)

# %%
X[X>15]
# Out:
# array([51, 55, 19])

# %% [markdown]
# ## 1.6 Matplotlib

# %% [markdown]
# ### 1.6.1 単純なグラフ

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(0,6,0.1)
y = np.sin(x)

plt.plot(x,y)
plt.show()

# %%
x = np.arange(0,6,0.1)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x,y1, label='sin')
plt.plot(x,y2, label='cos', linestyle='--')
plt.xlabel('x')
plt.ylabel('y')
plt.title('sin&cos')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.6.3 画像の表示

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('lena.png')
plt.imshow(img)

plt.show()
